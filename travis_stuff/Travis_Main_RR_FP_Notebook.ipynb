# %% [markdown]
# ## Travis RR - FP Analysis Pipeline

# %%
Uses the functions found in "function_defs"

# %%
#imports
import numpy as np 
import numpy as np
import pandas as pd
from matplotlib import pyplot as plt
import os
import re
import matplotlib as mpl
from matplotlib import rc

from functions_travis import *

# %%
#plot session results 
get_fp_plots('RRM001', 133, 'any_offer', 'green', 'left', 'reject', plot_flag='mean')
plt.show()
# Out:
# /Volumes/Wilbrecht_file_server/Restaurant Row/Data/fp_data/Cohort 3 D1/FP_Dayp133_epoch-8_ID-RRM001_2021-01-28T15_44_16.csv
# Pellets Revealed R1: 8
# Pellets Eaten R1: 8
# Pellets Revealed R2: 17
# Pellets Eaten R2: 17
# Pellets Revealed R3: 20
# Pellets Eaten R3: 20
# Pellets Revealed R4: 18
# Pellets Eaten R4: 18
