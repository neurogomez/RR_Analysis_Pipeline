% %% [markdown]
% # Restaurant Row: Behaviour Statistics in MatLab
%
% _Goal_ : Quantify statistics of different trial types, learning across sessions and how restaurant flavour preferences influence likelhood of choices

% %% [markdown]
% ## Trial Types
%
% - `reject`: left turn, reject offer
% - `quit`: right turn, quit before reward tone
% - `reward_taken`: right turn accept, reward offered and taken
% - `reward_available`:  right turn accept - reward offered but not taken
% - `reward_omission`: right turn accept, no-reward
%
% ## Variables to Comapre Across
% - 4 restaurants with 4 offer tones = 16 event types

% %% [markdown]
% ## Epoch Codes
% - Epoch 1: Variable Delay [0, 1, 1, 1, 1]
% - Epoch 2: Variable Delay [0, 0, 1, 1, 1]
% - Epoch 3: Variable Delay [0, 0, 0.8, 1, 1]
% - Epoch 4: Variable Delay [0, 0.2, 0.8, 1, 1]
% - Epoch 5: Variable Delay [0, 0.2 ,0.8, 1]
%
% ### Wait Times
% - 0%: 7 sec
% - 20%: 5 sec
% - 80%: 3 sec
% - 100%: 1 sec

% %%
addpath(genpath('../RR_Data'))

csv = 'RR_Day11_epoch-5_ID-RRM025_2021-03-26T13_44_23.csv';
behaviour_stat(csv)
% Out:
% Error using dlmread (line 122)
% The file 'RR_Day11_epoch-5_ID-RRM011_2021-03-26T15_01_35.csv' could not be opened because: No such file or directory
